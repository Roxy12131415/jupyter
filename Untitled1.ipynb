# %%
import numpy as np
import pandas as pd
train_agg = pd.read_csv('train/train_agg.csv',sep='\t')
train_flg = pd.read_csv('train/train_flg.csv',sep='\t')
train_agg.head(10)
# Out:
#         V1       V2       V3      V4       V5       V6       V7       V8  \
# 0 -1.92554 -0.90689 -1.26634  0.2892 -0.68454 -1.70618 -0.29641 -0.18761
# 1 -1.92554 -0.90689 -1.26634  0.2892 -0.68454 -1.70618  0.37601 -0.10030
# 2 -1.92554 -0.90689 -1.26634  0.2892 -0.68454 -1.57176  0.03980 -0.17089
# 3 -1.92554 -0.90689 -1.26634  0.2892 -0.68454 -1.30291 -0.29641 -0.18761
# 4 -1.92554 -0.90689 -1.26634  0.2892 -0.68454 -1.16849 -0.29641 -0.18761
# 5 -1.92554 -0.90689 -1.26634  0.2892 -0.68454 -1.16849 -0.29641 -0.18761
# 6 -1.92554 -0.90689 -1.26634  0.2892 -0.68454 -1.16849 -0.29641 -0.18761
# 7 -1.92554 -0.90689 -1.26634  0.2892 -0.68454 -1.16849 -0.29641 -0.18761
# 8 -1.92554 -0.90689 -1.26634  0.2892 -0.68454 -1.16849 -0.29641 -0.18761
# 9 -1.92554 -0.90689 -1.26634  0.2892 -0.68454 -1.16849 -0.29641 -0.18761
#
#         V9      V10  ...        V22      V23     V24      V25      V26  \
# 0 -0.48351 -0.53051  ...    0.15815 -0.16201  0.4762 -0.55917 -0.77398
# ...

# %%
train_flg.head()
# Out:
#    USRID  FLAG
# 0      0     0
# 1     35     0
# 2     42     0
# 3     76     0
# 4     77     0

# %%
data = pd.merge(train_agg,train_flg,on=['USRID'],how='left').sort_values(by=['V11','V15'] , ascending=False)[['V11','V15','FLAG']]
data[data['FLAG']==0]
# Out:
#              V11        V15  FLAG
# 8487   111.07872  177.90548     0
# 24580   45.93173   10.25416     0
# 42647   30.25521    0.04361     0
# 65240   29.13985   19.77225     0
# 70109   23.97199   -0.26002     0
# 67912   23.23637   -0.27218     0
# 51987   22.24756    0.17908     0
# 75967   20.12605   28.66072     0
# 48979   19.80659   -0.16078     0
# 56588   19.08932    8.51698     0
# 3428    18.60461   -0.04703     0
# 24678   17.09683   -0.27218     0
# 64710   17.04313   -0.22597     0
# 70244   16.58908   -0.19067     0
# 25822   16.48022    7.77416     0
# 41296   15.88726   -0.27218     0
# 49101   15.84427   -0.20965     0
# 40368   15.74014    6.91567     0
# 8846    15.71826   23.64371     0
# 48442   15.42484   19.67207     0
# 61145   15.18681   24.98638     0
# 8943    14.95454    2.74953     0
# 76049   14.65669   24.31283     0
# 1466    14.61337   -0.27218     0
# 56859   14.58183   -0.24829     0
# 32963   14.18937   23.44230     0
# ...
